# %%
import pandas as pd

# %%
data={"a":[12,72,34,56,78,90],"b":[36,78,90,56,74,12]}

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#     a   b
# 0  12  36
# 1  72  78
# 2  34  90
# 3  56  56
# 4  78  74

# %%
df.tail()
# Out:
#     a   b
# 1  72  78
# 2  34  90
# 3  56  56
# 4  78  74
# 5  90  12

# %%
df.count()
# Out:
# a    6
# b    6
# dtype: int64

# %%
df.sum()
# Out:
# a    342
# b    346
# dtype: int64

# %%
df.mean()
# Out:
# a    57.000000
# b    57.666667
# dtype: float64

# %%
df.median()
# Out:
# a    64.0
# b    65.0
# dtype: float64

# %%
df.mode()
# Out:
#     a   b
# 0  12  12
# 1  34  36
# 2  56  56
# 3  72  74
# 4  78  78
# 5  90  90

# %%
df.std()
# Out:
# a    29.359837
# b    29.268869
# dtype: float64

# %%
df.min()
# Out:
# a    12
# b    12
# dtype: int64

# %%
df.max()
# Out:
# a    90
# b    90
# dtype: int64

# %%
df.abs()
# Out:
#     a   b
# 0  12  36
# 1  72  78
# 2  34  90
# 3  56  56
# 4  78  74
# 5  90  12

# %%
df.prod()
# Out:
# a    11548293120
# b    12567260160
# dtype: int64

# %%
df.cumsum()
# Out:
#      a    b
# 0   12   36
# 1   84  114
# 2  118  204
# 3  174  260
# 4  252  334
# 5  342  346

# %%
df.cumprod()
# Out:
#              a            b
# 0           12           36
# 1          864         2808
# 2        29376       252720
# 3      1645056     14152320
# 4    128314368   1047271680
# 5  11548293120  12567260160

# %%
df.describe()
# Out:
#                a          b
# count   6.000000   6.000000
# mean   57.000000  57.666667
# std    29.359837  29.268869
# min    12.000000  12.000000
# 25%    39.500000  41.000000
# 50%    64.000000  65.000000
# 75%    76.500000  77.000000
# max    90.000000  90.000000
